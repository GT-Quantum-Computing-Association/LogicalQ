# %% [markdown]
# # Logical Gate Benchmarking

# %% [markdown]
# ## Imports

# %%
import numpy as np

import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 500

import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.circuit.library import XGate, YGate, ZGate, HGate, SGate, TGate, CXGate, CYGate, CZGate, RXGate, RYGate, RZGate
from qiskit.quantum_info import Statevector, state_fidelity

from LogicalQ.Logical import LogicalCircuit, LogicalStatevector, logical_state_fidelity, LogicalCircuitLegacy
from LogicalQ.Library.QECCs import steane_code
from LogicalQ.Library.HardwareModels import hardware_models_Quantinuum
from LogicalQ.Execution import execute_circuits
from LogicalQ.Analysis import counts_to_statevector

# %%
#plt.rcParams.update({
#    "text.usetex": True,
#    "text.latex.preamble": r"\usepackage{amsmath}",
#    "font.size": 18,
#    "font.family": "serif",
#})

# %% [markdown]
# ## Non-parametric gates

# %%
min_n_gates, max_n_gates, step_n_gates = 0, 4, 1
n_gates_data = np.pow(2, np.arange(min_n_gates, max_n_gates+1, step_n_gates))

# %%
data = {}

gates = [
    # Single-qubit gates
    XGate,
    YGate,
    ZGate,
    HGate,
    SGate,
    TGate,
    # Multi-qubit gates (slow!)
    # CXGate,
    # CYGate,
    # CZGate,
]

for idx, gate in enumerate(gates):
    
    print(idx, "start")
    # 1. Construct circuits
    qc_list = []
    lqc_list = []
    sv_exact_list = []
    for n_gates in n_gates_data:
        # a. Construct physical circuit
        qc_gate = QuantumCircuit(gate().num_qubits)
        qc_gate.append(gate(), list(range(gate().num_qubits)))
    
        # b. Construct logical circuit
        lqc_gate = LogicalCircuit.from_physical_circuit(qc_gate, **steane_code)#, num_ancillas=10)
        lqc_gate.append_qec_cycle()
        
        # c. Construct exact statevector
        sv_gate_exact = Statevector(qc_gate)

        qc_gate.measure_all()
        lqc_gate.measure_all()

        qc_list.append(qc_gate)
        lqc_list.append(lqc_gate)
        sv_exact_list.append(sv_gate_exact)

    # 2. Simulate circuits
    shots_physical = int(1E5)
    shots_logical = int(1E4)
    print(idx, "physical")
    results_physical = execute_circuits(
        qc_list,
        backend="aer_simulator",
        method="statevector",
        hardware_model=hardware_models_Quantinuum["H2-1"], coupling_map=None,
        shots=shots_physical,
    )
    
    print(idx, "logical")
    results_logical = execute_circuits(
        lqc_list,
        backend="aer_simulator",
        method="statevector",
        hardware_model=hardware_models_Quantinuum["H2-1"], coupling_map=None,
        shots=shots_logical,
    )

    # 3. Analyze results
    physical_data = []
    for sv_exact, result_physical in zip(sv_exact_list, results_physical):
        sv_physical = counts_to_statevector(result_physical.get_counts())
        fidelity_physical = state_fidelity(sv_exact, sv_physical)
        physical_data.append(fidelity_physical)
    logical_data = []
    for sv_exact, result_logical in zip(sv_exact_list, results_logical):
        sv_logical = LogicalStatevector.from_counts(result_logical.get_counts(), gate().num_qubits, **steane_code)
        fidelity_logical = logical_state_fidelity(sv_exact, sv_logical)
        logical_data.append(fidelity_logical)

    physical_data = np.round(physical_data, int(np.log10(shots_physical)+1))
    logical_data = np.round(logical_data, int(np.log10(shots_logical)+1))

    # n. Save data
    data[gate().name] = {
        "physical_data": physical_data,
        "logical_data": logical_data,
    }

data

# %% [markdown]
# Plotting Fidelity Results:

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import array

gates = list(data.keys())
depths = n_gates_data
x_indices = np.arange(len(depths))
width = 0.35

fig, axs = plt.subplots(2, 3, figsize=(16, 10), sharey=True)
fig.suptitle('Physical vs. Logical Fidelity by Gate Type and Circuit Depth', fontsize=16)
axs = axs.flatten()

phys_color = '#1f77b4'  # Standard MPL Blue
log_color = '#ff7f0e'   # Standard MPL Orange

for i, gate in enumerate(gates):
    phys = data[gate]['physical_data']
    logi = data[gate]['logical_data']
    
    axs[i].bar(x_indices - width/2, phys, width, label='Physical', color=phys_color, alpha=0.8)
    axs[i].bar(x_indices + width/2, logi, width, label='Logical', color=log_color, alpha=0.8)
    
    axs[i].set_title(f'Gate: {gate.upper()}', fontsize=12)
    axs[i].set_xticks(x_indices)
    axs[i].set_xticklabels(depths)
    axs[i].grid(axis='y', linestyle='--', alpha=0.3)
    
    if i == 0:
        axs[i].legend(loc='lower right')

fig.text(0.5, 0.04, 'Number of Gates (Depth)', ha='center', fontsize=14)
fig.text(0.04, 0.5, 'Fidelity', va='center', rotation='vertical', fontsize=14)

plt.ylim(0.85, 1.01)

plt.tight_layout(rect=[0.05, 0.05, 1, 0.95])
plt.show()

# %% [markdown]
# Single Gate Testing

# %%
gate = TGate

qc_gate = QuantumCircuit(gate().num_qubits)
for _ in range(1):
    qc_gate.append(gate(), list(range(gate().num_qubits)))

lqc_gate = LogicalCircuit.from_physical_circuit(qc_gate, **steane_code, num_ancillas=4)
#lqc_gate.append_qec_cycle()

sv_gate_exact = Statevector(qc_gate)

qc_gate.measure_all()
lqc_gate.measure_all()

results_physical = execute_circuits(
    qc_gate,
    backend="aer_simulator",
    method="statevector",
    hardware_model=hardware_models_Quantinuum["H2-1"], coupling_map=None,
    shots=1E5,
)
results_logical = execute_circuits(
    lqc_gate,
    backend="aer_simulator",
    method="statevector",
    hardware_model=hardware_models_Quantinuum["H2-1"], coupling_map=None,
    shots=1000,
)

sv_physical = counts_to_statevector(results_physical[0].get_counts())
fidelity_physical = state_fidelity(sv_gate_exact, sv_physical)

sv_logical = LogicalStatevector.from_counts(results_logical[0].get_counts(), gate().num_qubits, **steane_code)
fidelity_logical = logical_state_fidelity(sv_gate_exact, sv_logical)
fidelity_physical, fidelity_logical

# %%
lqc_gate.draw(output='mpl', fold=-1)

# %%
lqc_gate.decompose().draw(output='mpl', fold=-1)

# %%
gate = TGate

qc_gate = QuantumCircuit(gate().num_qubits)
for _ in range(1):
    qc_gate.append(gate(), list(range(gate().num_qubits)))


from LogicalQ.Logical import LogicalCircuitLegacy
lqc_gate = LogicalCircuitLegacy.from_physical_circuit(qc_gate, **steane_code)
#lqc_gate.append_qec_cycle()

sv_gate_exact = Statevector(qc_gate)

qc_gate.measure_all()
lqc_gate.measure_all()

results_physical = execute_circuits(
    qc_gate,
    backend="aer_simulator",
    method="statevector",
    hardware_model=hardware_models_Quantinuum["H2-1"], coupling_map=None,
    shots=1E5,
)
results_logical = execute_circuits(
    lqc_gate,
    backend="aer_simulator",
    method="statevector",
    hardware_model=hardware_models_Quantinuum["H2-1"], coupling_map=None,
    shots=1000,
)

sv_physical = counts_to_statevector(results_physical[0].get_counts())
fidelity_physical = state_fidelity(sv_gate_exact, sv_physical)

sv_logical = LogicalStatevector.from_counts(results_logical[0].get_counts(), gate().num_qubits, **steane_code)
fidelity_logical = logical_state_fidelity(sv_gate_exact, sv_logical)
fidelity_physical, fidelity_logical
